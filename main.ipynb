# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import xgboost as xgb

# %%
train_df = pd.read_csv("training.csv", sep="\t")
valid_df = pd.read_csv("validation.csv", sep="\t")

# %%
train_df.head()
# Out:
#   DepartureDate  DepartureYear  DepartureMonth  DepartureDay  FlightNumber  \
# 0    01/10/2016           2016              10             1          1145
# 1    01/10/2016           2016              10             1          1160
# 2    01/10/2016           2016              10             1          1183
# 3    01/10/2016           2016              10             1          1220
# 4    01/10/2016           2016              10             1          1225
#
#   DepartureAirport ArrivalAirport    Route  ActualFlightTime  ActualTotalFuel  \
# 0              MAN            SXF  MAN-SXF                91             3660
# 1              CTA            FCO  CTA-FCO                68             3280
# 2              LGW            SNN  LGW-SNN                64             2720
# 3              ATH            CHQ  ATH-CHQ                35             1682
# 4              CHQ            ATH  CHQ-ATH                34             1877
#
#   ActualTOW FLownPassengers BagsCount FlightBagsWeight
# 0     64016             175        61              440
# 1     66138             182        27              350
# 2     58447             127    (null)           (null)
# 3     60587             163        12              150
# 4     63090             178        37              490

# %%
valid_df.head()
# Out:
#   DepartureDate  DepartureYear  DepartureMonth  DepartureDay  FlightNumber  \
# 0    01/11/2016           2016              11             1          6003
# 1    01/11/2016           2016              11             1          6004
# 2    01/11/2016           2016              11             1          6542
# 3    01/11/2016           2016              11             1          6541
# 4    01/11/2016           2016              11             1          5542
#
#   DepartureAirport ArrivalAirport    Route  ActualFlightTime  ActualTotalFuel  \
# 0              MRS            BES  MRS-BES                84             3630
# 1              BES            MRS  BES-MRS                86             3690
# 2              MRS            STN  MRS-STN               100             4390
# 3              STN            MRS  STN-MRS               100             4690
# 4              STN            REU  STN-REU               112             4900
#
#   FLownPassengers BagsCount FlightBagsWeight
# 0             185        43              560
# 1             188    (null)           (null)
# 2             168        55              720
# 3             185        35              460
# 4             167        31              400

# %%
print(f"Training data: {len(train_df)}")
print(f"Validation data: {len(valid_df)}")
# Out:
# Training data: 29731
# Validation data: 1878

# %%
print(train_df.columns)
# Out:
# Index(['DepartureDate', 'DepartureYear', 'DepartureMonth', 'DepartureDay',
#        'FlightNumber', 'DepartureAirport', 'ArrivalAirport', 'Route',
#        'ActualFlightTime', 'ActualTotalFuel', 'ActualTOW', 'FLownPassengers',
#        'BagsCount', 'FlightBagsWeight'],
#       dtype='object')

# %%
train_df.rename(columns={'FLownPassengers': 'FlownPassengers'}, inplace=True)

# %%
print(valid_df.columns)
# Out:
# Index(['DepartureDate', 'DepartureYear', 'DepartureMonth', 'DepartureDay',
#        'FlightNumber', 'DepartureAirport', 'ArrivalAirport', 'Route',
#        'ActualFlightTime', 'ActualTotalFuel', 'FLownPassengers', 'BagsCount',
#        'FlightBagsWeight'],
#       dtype='object')

# %%
valid_df.rename(columns={'FLownPassengers': 'FlownPassengers'}, inplace=True)

# %%
print(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29731 entries, 0 to 29730
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DepartureDate     29731 non-null  object
#  1   DepartureYear     29731 non-null  int64
#  2   DepartureMonth    29731 non-null  int64
#  3   DepartureDay      29731 non-null  int64
#  4   FlightNumber      29731 non-null  int64
#  5   DepartureAirport  29731 non-null  object
#  6   ArrivalAirport    29731 non-null  object
#  7   Route             29731 non-null  object
#  8   ActualFlightTime  29731 non-null  int64
#  9   ActualTotalFuel   29731 non-null  int64
#  10  ActualTOW         29731 non-null  object
#  11  FlownPassengers   29731 non-null  object
#  12  BagsCount         29731 non-null  object
#  13  FlightBagsWeight  29731 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.2+ MB
# None

# %%
numeric_columns = ['ActualFlightTime', 'ActualTotalFuel', 'ActualTOW',
                   'FlownPassengers', 'BagsCount', 'FlightBagsWeight']

for col in numeric_columns:
    if col in train_df.columns:
        train_df[col] = pd.to_numeric(train_df[col], errors='coerce')

# %%
print(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29731 entries, 0 to 29730
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DepartureDate     29731 non-null  object
#  1   DepartureYear     29731 non-null  int64
#  2   DepartureMonth    29731 non-null  int64
#  3   DepartureDay      29731 non-null  int64
#  4   FlightNumber      29731 non-null  int64
#  5   DepartureAirport  29731 non-null  object
#  6   ArrivalAirport    29731 non-null  object
#  7   Route             29731 non-null  object
#  8   ActualFlightTime  29731 non-null  int64
#  9   ActualTotalFuel   29731 non-null  int64
#  10  ActualTOW         29298 non-null  float64
#  11  FlownPassengers   29636 non-null  float64
#  12  BagsCount         27447 non-null  float64
#  13  FlightBagsWeight  27253 non-null  float64
# dtypes: float64(4), int64(6), object(4)
# memory usage: 3.2+ MB
# None

# %%
train_df["DepartureDate"] = pd.to_datetime(train_df["DepartureDate"], format="%d/%m/%Y")
train_df["DayOfWeek"] = train_df["DepartureDate"].dt.weekday

train_df["FuelPerMinute"] = train_df["ActualTotalFuel"] / train_df["ActualFlightTime"]
train_df['FuelPerPassenger'] = train_df['ActualTotalFuel'] / (train_df['FlownPassengers'])


train_df["PassengersPerBag"] = train_df["FlownPassengers"] / train_df["BagsCount"]
train_df['AvgBagWeight'] = train_df['FlightBagsWeight'] / (train_df['BagsCount'])


train_df['IsWeekend'] = train_df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
print(train_df['IsWeekend'].value_counts())
# Out:
# IsWeekend
# 0    19950
# 1     9781
# Name: count, dtype: int64

# %%
train_df.head()
# Out:
#   DepartureDate  DepartureYear  DepartureMonth  DepartureDay  FlightNumber  \
# 0    2016-10-01           2016              10             1          1145
# 1    2016-10-01           2016              10             1          1160
# 2    2016-10-01           2016              10             1          1183
# 3    2016-10-01           2016              10             1          1220
# 4    2016-10-01           2016              10             1          1225
#
#   DepartureAirport ArrivalAirport    Route  ActualFlightTime  ActualTotalFuel  \
# 0              MAN            SXF  MAN-SXF                91             3660
# 1              CTA            FCO  CTA-FCO                68             3280
# 2              LGW            SNN  LGW-SNN                64             2720
# 3              ATH            CHQ  ATH-CHQ                35             1682
# 4              CHQ            ATH  CHQ-ATH                34             1877
#
#    ActualTOW  FlownPassengers  BagsCount  FlightBagsWeight  DayOfWeek  \
# 0    64016.0            175.0       61.0             440.0          5
# 1    66138.0            182.0       27.0             350.0          5
# 2    58447.0            127.0        NaN               NaN          5
# 3    60587.0            163.0       12.0             150.0          5
# 4    63090.0            178.0       37.0             490.0          5
#
#    FuelPerMinute  FuelPerPassenger  PassengersPerBag  AvgBagWeight  IsWeekend
# 0      40.219780         20.914286          2.868852      7.213115          1
# 1      48.235294         18.021978          6.740741     12.962963          1
# 2      42.500000         21.417323               NaN           NaN          1
# 3      48.057143         10.319018         13.583333     12.500000          1
# 4      55.205882         10.544944          4.810811     13.243243          1

# %%
n_missing_rows = train_df.isnull().any(axis=1).sum()
n_complete_rows = train_df.shape[0] - n_missing_rows

print(f"Missing rows: {n_missing_rows}")
print(f"Full rows: {n_complete_rows}")
# Out:
# Missing rows: 2931
# Full rows: 26800

# %%
print(train_df.isna().sum())
# Out:
# DepartureDate          0
# DepartureYear          0
# DepartureMonth         0
# DepartureDay           0
# FlightNumber           0
# DepartureAirport       0
# ArrivalAirport         0
# Route                  0
# ActualFlightTime       0
# ActualTotalFuel        0
# ActualTOW            433
# FlownPassengers       95
# BagsCount           2284
# FlightBagsWeight    2478
# DayOfWeek              0
# FuelPerMinute          0
# FuelPerPassenger      95
# PassengersPerBag    2284
# AvgBagWeight        2589
# IsWeekend              0
# dtype: int64

# %%
train_df = train_df.dropna()

# %%
print(train_df.isna().sum())
# Out:
# DepartureDate       0
# DepartureYear       0
# DepartureMonth      0
# DepartureDay        0
# FlightNumber        0
# DepartureAirport    0
# ArrivalAirport      0
# Route               0
# ActualFlightTime    0
# ActualTotalFuel     0
# ActualTOW           0
# FlownPassengers     0
# BagsCount           0
# FlightBagsWeight    0
# DayOfWeek           0
# FuelPerMinute       0
# FuelPerPassenger    0
# PassengersPerBag    0
# AvgBagWeight        0
# IsWeekend           0
# dtype: int64

# %%
num_duplicates = train_df.duplicated().sum()

if num_duplicates > 0:
    print(f"Found {num_duplicates} duplicates:")
    display(train_df[train_df.duplicated()].head())
else:
    print("No duplicates.")
# Out:
# No duplicates.

# %%
print(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26800 entries, 0 to 29730
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DepartureDate     26800 non-null  datetime64[ns]
#  1   DepartureYear     26800 non-null  int64
#  2   DepartureMonth    26800 non-null  int64
#  3   DepartureDay      26800 non-null  int64
#  4   FlightNumber      26800 non-null  int64
#  5   DepartureAirport  26800 non-null  object
#  6   ArrivalAirport    26800 non-null  object
#  7   Route             26800 non-null  object
#  8   ActualFlightTime  26800 non-null  int64
#  9   ActualTotalFuel   26800 non-null  int64
#  10  ActualTOW         26800 non-null  float64
#  11  FlownPassengers   26800 non-null  float64
#  12  BagsCount         26800 non-null  float64
#  13  FlightBagsWeight  26800 non-null  float64
#  14  DayOfWeek         26800 non-null  int32
#  15  FuelPerMinute     26800 non-null  float64
#  16  FuelPerPassenger  26800 non-null  float64
#  17  PassengersPerBag  26800 non-null  float64
#  18  AvgBagWeight      26800 non-null  float64
#  19  IsWeekend         26800 non-null  int32
# dtypes: datetime64[ns](1), float64(8), int32(2), int64(6), object(3)
# memory usage: 4.1+ MB
# None

# %%
train_df.drop(columns=["DepartureDate", "FlightNumber"], inplace=True)

# %%
print(train_df.columns)
# Out:
# Index(['DepartureYear', 'DepartureMonth', 'DepartureDay', 'DepartureAirport',
#        'ArrivalAirport', 'Route', 'ActualFlightTime', 'ActualTotalFuel',
#        'ActualTOW', 'FlownPassengers', 'BagsCount', 'FlightBagsWeight',
#        'DayOfWeek', 'FuelPerMinute', 'FuelPerPassenger', 'PassengersPerBag',
#        'AvgBagWeight', 'IsWeekend'],
#       dtype='object')

# %%
all_features = ['DepartureYear', 'DepartureMonth', 'DepartureDay',
       'DepartureAirport', 'ArrivalAirport', 'Route', 'ActualFlightTime',
       'ActualTotalFuel', 'FlownPassengers', 'BagsCount',
       'FlightBagsWeight', 'DayOfWeek', 'FuelPerMinute', 'FuelPerPassenger',
       'PassengersPerBag', 'AvgBagWeight', 'IsWeekend']

X = train_df[all_features].copy()
y = train_df['ActualTOW']

# %%
for col in X.select_dtypes(include='object').columns:
    X[col] = X[col].astype('category')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
import optuna


def objective(trial):

    selected_features = [f for f in all_features if trial.suggest_categorical(f'use_{f}', [True, False])]
    if len(selected_features) == 0:
        return float('inf') 

    X_selected = X[selected_features]

    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 5),
        'tree_method': 'hist',
        'enable_categorical': True,
        'random_state': 42,
    }

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    y_bins = pd.qcut(y, q=10, duplicates='drop', labels=False)
    mse_scores = []

    for train_idx, val_idx in skf.split(X_selected, y_bins):
        X_train, X_val = X_selected.iloc[train_idx], X_selected.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model = XGBRegressor(**params)
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            verbose=False
        )
        y_pred = model.predict(X_val)
        mse_scores.append(mean_squared_error(y_val, y_pred))

    return np.mean(mse_scores)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=400)

print("Best parameters:")
print(study.best_params)
print(f"Best MSE: {study.best_value:.2f}")

best_features = [f for f in all_features if study.best_params.get(f'use_' + f, False)]
print("Features:")
print(best_features)
# Out:
# [I 2025-05-29 12:59:29,991] A new study created in memory with name: no-name-3153e7ca-831d-4b6b-a769-307fcb0b87bf
# [I 2025-05-29 13:00:55,010] Trial 0 finished with value: 1465799.2352596384 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': False, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': False, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': True, 'use_AvgBagWeight': True, 'use_IsWeekend': False, 'n_estimators': 414, 'max_depth': 9, 'learning_rate': 0.06969161685456265, 'subsample': 0.8916623345919852, 'colsample_bytree': 0.9374584847963141, 'gamma': 1.9219895307328434, 'reg_alpha': 3.777290754827533, 'reg_lambda': 1.1533615042484207}. Best is trial 0 with value: 1465799.2352596384.
# [I 2025-05-29 13:01:23,440] Trial 1 finished with value: 679594.7099232723 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': True, 'use_Route': True, 'use_ActualFlightTime': False, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 488, 'max_depth': 5, 'learning_rate': 0.1187761662991709, 'subsample': 0.736368321906387, 'colsample_bytree': 0.8884330153316427, 'gamma': 2.3689940054362832, 'reg_alpha': 4.852430568443216, 'reg_lambda': 2.049519462865593}. Best is trial 1 with value: 679594.7099232723.
# [I 2025-05-29 13:02:50,935] Trial 2 finished with value: 738453.6145042613 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': False, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': False, 'n_estimators': 423, 'max_depth': 9, 'learning_rate': 0.1290548858018855, 'subsample': 0.8726549199898034, 'colsample_bytree': 0.7967796169592678, 'gamma': 4.580329647779236, 'reg_alpha': 0.2789996537364453, 'reg_lambda': 3.7233109935641773}. Best is trial 1 with value: 679594.7099232723.
# [I 2025-05-29 13:04:00,953] Trial 3 finished with value: 1725933.7821138748 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': True, 'use_DepartureDay': False, 'use_DepartureAirport': True, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': False, 'use_BagsCount': False, 'use_FlightBagsWeight': False, 'use_DayOfWeek': True, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': False, 'use_IsWeekend': False, 'n_estimators': 494, 'max_depth': 9, 'learning_rate': 0.11113614527011766, 'subsample': 0.6929055734261693, 'colsample_bytree': 0.7357212051894713, 'gamma': 3.3830830206533067, 'reg_alpha': 3.94654500787221, 'reg_lambda': 3.0360208167569973}. Best is trial 1 with value: 679594.7099232723.
# [I 2025-05-29 13:04:19,991] Trial 4 finished with value: 577362.7537844877 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': False, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 439, 'max_depth': 4, 'learning_rate': 0.13178237620630737, 'subsample': 0.7772033942126773, 'colsample_bytree': 0.7267254420398767, 'gamma': 1.7027250522863502, 'reg_alpha': 2.049139922552174, 'reg_lambda': 2.141086857500498}. Best is trial 4 with value: 577362.7537844877.
# [I 2025-05-29 13:04:29,416] Trial 5 finished with value: 2279537.9268711973 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': True, 'use_Route': True, 'use_ActualFlightTime': False, 'use_ActualTotalFuel': False, 'use_FlownPassengers': False, 'use_BagsCount': True, 'use_FlightBagsWeight': True, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': True, 'use_AvgBagWeight': True, 'use_IsWeekend': False, 'n_estimators': 167, 'max_depth': 6, 'learning_rate': 0.017285025131245284, 'subsample': 0.6377593396322078, 'colsample_bytree': 0.6238178338414907, 'gamma': 4.966849126018954, 'reg_alpha': 1.2936946630642292, 'reg_lambda': 4.657701131150888}. Best is trial 4 with value: 577362.7537844877.
# [I 2025-05-29 13:04:34,135] Trial 6 finished with value: 1946601.6200063997 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': False, 'use_ActualFlightTime': False, 'use_ActualTotalFuel': True, 'use_FlownPassengers': False, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': False, 'use_IsWeekend': False, 'n_estimators': 381, 'max_depth': 5, 'learning_rate': 0.08356855279690785, 'subsample': 0.9638524732233688, 'colsample_bytree': 0.9409587615949052, 'gamma': 4.439020001946506, 'reg_alpha': 1.582362899507777, 'reg_lambda': 3.4246762905149533}. Best is trial 4 with value: 577362.7537844877.
# [I 2025-05-29 13:04:38,398] Trial 7 finished with value: 1059720.3685857574 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': False, 'use_ActualFlightTime': False, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 232, 'max_depth': 6, 'learning_rate': 0.08736444613479495, 'subsample': 0.6236504197948274, 'colsample_bytree': 0.8837325641624117, 'gamma': 1.546433013861973, 'reg_alpha': 3.729555656881693, 'reg_lambda': 0.5774692578070711}. Best is trial 4 with value: 577362.7537844877.
# [I 2025-05-29 13:04:42,547] Trial 8 finished with value: 1072571.6680739312 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': False, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': True, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': True, 'use_AvgBagWeight': True, 'use_IsWeekend': False, 'n_estimators': 292, 'max_depth': 3, 'learning_rate': 0.1840349356789594, 'subsample': 0.7681562590474436, 'colsample_bytree': 0.629543596433785, 'gamma': 2.9281187453354325, 'reg_alpha': 4.062629426624362, 'reg_lambda': 2.0565663413438036}. Best is trial 4 with value: 577362.7537844877.
# [I 2025-05-29 13:05:03,144] Trial 9 finished with value: 580362.50737973 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': False, 'use_AvgBagWeight': False, 'use_IsWeekend': False, 'n_estimators': 279, 'max_depth': 6, 'learning_rate': 0.027535575750647003, 'subsample': 0.8268935716344845, 'colsample_bytree': 0.8184995647941637, 'gamma': 0.5990003800238891, 'reg_alpha': 4.841562531283598, 'reg_lambda': 0.0533105826852448}. Best is trial 4 with value: 577362.7537844877.
# [I 2025-05-29 13:05:04,927] Trial 10 finished with value: 611890.4936050295 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': False, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators':
. Best is trial 31 with value: 486738.0749261611.
# [I 2025-05-29 13:14:18,655] Trial 39 finished with value: 1009426.8404389333 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': False, 'use_DepartureAirport': False, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': False, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 473, 'max_depth': 6, 'learning_rate': 0.09701760763230396, 'subsample': 0.6768030276275551, 'colsample_bytree': 0.6491916642991967, 'gamma': 1.650414598568478, 'reg_alpha': 4.619365790086585, 'reg_lambda': 3.414110140683963}. Best is trial 31 with value: 486738.0749261611.
# [I 2025-05-29 13:14:37,686] Trial 40 finished with value: 521175.2985063604 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': False, 'n_estimators': 386, 'max_depth': 5, 'learning_rate': 0.12466111241480365, 'subsample': 0.7277296449261226, 'colsample_bytree': 0.6852198665033269, 'gamma': 3.7800638828058855, 'reg_alpha': 4.989665150020075, 'reg_lambda': 4.601795899405183}. Best is trial 31 with value: 486738.0749261611.
# [I 2025-05-29 13:14:49,567] Trial 41 finished with value: 494176.38746768667 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 395, 'max_depth': 3, 'learning_rate': 0.10519066986937867, 'subsample': 0.7711543332303223, 'colsample_bytree': 0.6674993356062754, 'gamma': 0.7949531816682026, 'reg_alpha': 4.211452667950454, 'reg_lambda': 4.300622934070982}. Best is trial 31 with value: 486738.0749261611.
# [I 2025-05-29 13:15:04,299] Trial 42 finished with value: 487299.9135484621 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 424, 'max_depth': 4, 'learning_rate': 0.1087760362239705, 'subsample': 0.7563254135879712, 'colsample_bytree': 0.6507263930562321, 'gamma': 0.395244499788849, 'reg_alpha': 4.566609591108078, 'reg_lambda': 4.038723359215947}. Best is trial 31 with value: 486738.0749261611.
# [I 2025-05-29 13:15:19,247] Trial 43 finished with value: 486463.9299926752 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 432, 'max_depth': 4, 'learning_rate': 0.08516820380760479, 'subsample': 0.8024169443108172, 'colsample_bytree': 0.6285109062894985, 'gamma': 0.41839400979446745, 'reg_alpha': 4.635400560422884, 'reg_lambda': 4.627875464968019}. Best is trial 43 with value: 486463.9299926752.
# [I 2025-05-29 13:15:34,378] Trial 44 finished with value: 484092.3077328297 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 443, 'max_depth': 4, 'learning_rate': 0.0824152746147846, 'subsample': 0.7977845251797558, 'colsample_bytree': 0.6237452365660571, 'gamma': 0.4494431775416611, 'reg_alpha': 3.8412835281586277, 'reg_lambda': 4.6859987425953165}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:15:40,393] Trial 45 finished with value: 793327.4061493136 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 431, 'max_depth': 5, 'learning_rate': 0.0841102675850819, 'subsample': 0.8080492258167007, 'colsample_bytree': 0.6292452356895084, 'gamma': 0.3974062101570479, 'reg_alpha': 3.986498208807409, 'reg_lambda': 4.080493509691786}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:15:57,108] Trial 46 finished with value: 574394.0844310835 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': False, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': False, 'n_estimators': 446, 'max_depth': 4, 'learning_rate': 0.0757122746364718, 'subsample': 0.785290707777627, 'colsample_bytree': 0.7218087598936639, 'gamma': 0.09484806829086545, 'reg_alpha': 3.500843884007402, 'reg_lambda': 4.761622724632103}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:16:28,171] Trial 47 finished with value: 519884.6118844809 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': True, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 484, 'max_depth': 6, 'learning_rate': 0.06022436566351988, 'subsample': 0.7968567983438748, 'colsample_bytree': 0.6358310003965081, 'gamma': 0.5521184180341615, 'reg_alpha': 3.8457461559669093, 'reg_lambda': 4.401459632417983}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:16:43,819] Trial 48 finished with value: 493386.0614455288 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': True, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 456, 'max_depth': 4, 'learning_rate': 0.08983026812519576, 'subsample': 0.7733584701756868, 'colsample_bytree': 0.6197465913138105, 'gamma': 0.33624568747078426, 'reg_alpha': 4.724984747131442, 'reg_lambda': 4.999188985849905}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:17:16,982] Trial 49 finished with value: 564998.6447801072 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': False, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': False, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 432, 'max_depth': 7, 'learning_rate': 0.04078208283898264, 'subsample': 0.6471224186973555, 'colsample_bytree': 0.6912508720514495, 'gamma': 0.21152114829614857, 'reg_alpha': 4.092472949560406, 'reg_lambda': 1.8196402953604807}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:17:21,233] Trial 50 finished with value: 1301957.5851024904 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': False, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': False, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 319, 'max_depth': 3, 'learning_rate': 0.13614851277010953, 'subsample': 0.8108246264641549, 'colsample_bytree': 0.7279956708403408, 'gamma': 1.0045911329118151, 'reg_alpha': 4.404084039733305, 'reg_lambda': 3.433214629035879}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:17:36,050] Trial 51 finished with value: 486453.9524597515 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 419, 'max_depth': 4, 'learning_rate': 0.10100102382766467, 'subsample': 0.7382334698849116, 'colsample_bytree': 0.6199726227341997, 'gamma': 0.6312845966110671, 'reg_alpha': 4.57292508439424, 'reg_lambda': 4.65568513496299}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:17:50,995] Trial 52 finished with value: 485385.85498149414 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 423, 'max_depth': 4, 'learning_rate': 0.08760601344294786, 'subsample': 0.7077886645294448, 'colsample_bytree': 0.6448697880516764, 'gamma': 0.6294637375657268, 'reg_alpha': 4.774926006571436, 'reg_lambda': 4.747955646995021}. Best is trial 44 with value: 484092.3077328297.
# [I 2025-05-29 13:18:07,357] Trial 53 finished with value: 483776.4579074313 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 482, 'max_depth': 4, 'learning_rate': 0.0823006938448898, 'subsample': 0.7018508087990608, 'colsample_bytree': 0.6225876869562601, 'gamma': 0.619757426842518, 'reg_alpha': 4.555437537185186, 'reg_lambda': 4.744011292275787}. Best is trial 53 with value: 483776.4579074313.
# [I 2025-05-29 13:18:20,348] Trial 54 finished with value: 488580.90170392004 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': False, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': True, 'use_PassengersPerBag': True, 'use_AvgBagWeight': False, 'use_IsWeekend': True, 'n_estimators': 482, 'max_depth': 3, 'learning_rate': 0.07771534275316386, 'subsample': 0.695414178435639, 'colsample_bytree': 0.6200618539543211, 'gamma': 0.6350435163168042, 'reg_alpha': 4.766423043351032, 'reg_lambda': 4.711188469108356}. Best is trial 53 with value: 483776.4579074313.
# [I 2025-05-29 13:18:42,553] Trial 55 finished with value: 500839.7918561383 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': False, 'use_DepartureDay': True, 'use_DepartureAirport': False, 'use_ArrivalAirport': False, 'use_Route': True, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': True, 'use_FlightBagsWeight': False, 'use_DayOfWeek': False, 'use_FuelPerMinute': True, 'use_FuelPerPassenger
and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 482, 'max_depth': 5, 'learning_rate': 0.08575267567962445, 'subsample': 0.9619175896216866, 'colsample_bytree': 0.6473302783956127, 'gamma': 1.1127126883888052, 'reg_alpha': 1.6022691231334973, 'reg_lambda': 1.4432623054279308}. Best is trial 323 with value: 465691.7721393967.
# [I 2025-05-29 14:28:24,349] Trial 393 finished with value: 508957.6719069312 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': False, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 483, 'max_depth': 5, 'learning_rate': 0.08087749661756065, 'subsample': 0.9600808477643079, 'colsample_bytree': 0.6451104949323315, 'gamma': 1.392309727726816, 'reg_alpha': 1.5889193392858043, 'reg_lambda': 1.5086608205699645}. Best is trial 323 with value: 465691.7721393967.
# [I 2025-05-29 14:28:37,212] Trial 394 finished with value: 469843.66037132544 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 492, 'max_depth': 5, 'learning_rate': 0.08479392345124763, 'subsample': 0.949614645100561, 'colsample_bytree': 0.6443049763804981, 'gamma': 1.118816024979781, 'reg_alpha': 1.5822494092916521, 'reg_lambda': 1.4545099872766316}. Best is trial 323 with value: 465691.7721393967.
# [I 2025-05-29 14:28:48,922] Trial 395 finished with value: 476131.5024205785 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': False, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 482, 'max_depth': 5, 'learning_rate': 0.08807542837416898, 'subsample': 0.9419886597920479, 'colsample_bytree': 0.731862512331628, 'gamma': 1.2304233446733883, 'reg_alpha': 1.389380857140703, 'reg_lambda': 1.2295721294801307}. Best is trial 323 with value: 465691.7721393967.
# [I 2025-05-29 14:29:00,342] Trial 396 finished with value: 469156.38384978625 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 480, 'max_depth': 5, 'learning_rate': 0.07868332089933032, 'subsample': 0.9616457865864818, 'colsample_bytree': 0.6494741378379199, 'gamma': 1.0984792802234935, 'reg_alpha': 2.2909393465412284, 'reg_lambda': 1.408459877863649}. Best is trial 323 with value: 465691.7721393967.
# [I 2025-05-29 14:29:11,936] Trial 397 finished with value: 469447.59331582766 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 492, 'max_depth': 5, 'learning_rate': 0.08593528445731946, 'subsample': 0.9538954082018689, 'colsample_bytree': 0.6544495157556369, 'gamma': 1.0041596447993868, 'reg_alpha': 1.6091349737058551, 'reg_lambda': 1.0751063630541158}. Best is trial 323 with value: 465691.7721393967.
# [I 2025-05-29 14:29:22,686] Trial 398 finished with value: 474256.1843433346 and parameters: {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': False, 'n_estimators': 465, 'max_depth': 5, 'learning_rate': 0.08077133629007716, 'subsample': 0.9813120802509719, 'colsample_bytree': 0.6465596605394409, 'gamma': 1.2678502241169187, 'reg_alpha': 1.5259620523769086, 'reg_lambda': 1.3324113117137502}. Best is trial 323 with value: 465691.7721393967.
# [I 2025-05-29 14:29:31,949] Trial 399 finished with value: 551599.0950951062 and parameters: {'use_DepartureYear': False, 'use_DepartureMonth': True, 'use_DepartureDay': False, 'use_DepartureAirport': False, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 478, 'max_depth': 5, 'learning_rate': 0.08851202978222368, 'subsample': 0.9450918742175405, 'colsample_bytree': 0.672439310752921, 'gamma': 0.8721020840230793, 'reg_alpha': 1.379179140836837, 'reg_lambda': 1.7162772511636297}. Best is trial 323 with value: 465691.7721393967.
# Best parameters:
# {'use_DepartureYear': True, 'use_DepartureMonth': True, 'use_DepartureDay': True, 'use_DepartureAirport': True, 'use_ArrivalAirport': True, 'use_Route': False, 'use_ActualFlightTime': True, 'use_ActualTotalFuel': True, 'use_FlownPassengers': True, 'use_BagsCount': False, 'use_FlightBagsWeight': True, 'use_DayOfWeek': True, 'use_FuelPerMinute': True, 'use_FuelPerPassenger': False, 'use_PassengersPerBag': False, 'use_AvgBagWeight': True, 'use_IsWeekend': True, 'n_estimators': 470, 'max_depth': 4, 'learning_rate': 0.09694081261961722, 'subsample': 0.9214753371833588, 'colsample_bytree': 0.6674115091571178, 'gamma': 0.8418003889366719, 'reg_alpha': 1.5778679003672926, 'reg_lambda': 2.1406100860160375}
# Best MSE: 465691.77
# Features:
# ['DepartureYear', 'DepartureMonth', 'DepartureDay', 'DepartureAirport', 'ArrivalAirport', 'ActualFlightTime', 'ActualTotalFuel', 'FlownPassengers', 'FlightBagsWeight', 'DayOfWeek', 'FuelPerMinute', 'AvgBagWeight', 'IsWeekend']

# %%
from xgboost import XGBRegressor
import joblib

best_features = [f for f in all_features if study.best_params.get(f'use_' + f, False)]
best_params = {k: v for k, v in study.best_params.items() if not k.startswith('use_')}

final_model = XGBRegressor(
    **best_params,
    tree_method='hist',
    enable_categorical=True,
    random_state=42
)

X_final = X[best_features]
final_model.fit(X_final, y)

joblib.dump(final_model, 'best_xgb_model.pkl')
print("Saved as 'best_xgb_model.pkl'")
# Out:
# Saved as 'best_xgb_model.pkl'

# %%
print(valid_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1878 entries, 0 to 1877
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DepartureDate     1878 non-null   object
#  1   DepartureYear     1878 non-null   int64
#  2   DepartureMonth    1878 non-null   int64
#  3   DepartureDay      1878 non-null   int64
#  4   FlightNumber      1878 non-null   int64
#  5   DepartureAirport  1878 non-null   object
#  6   ArrivalAirport    1878 non-null   object
#  7   Route             1878 non-null   object
#  8   ActualFlightTime  1878 non-null   int64
#  9   ActualTotalFuel   1878 non-null   int64
#  10  FlownPassengers   1878 non-null   object
#  11  BagsCount         1878 non-null   object
#  12  FlightBagsWeight  1878 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 190.9+ KB
# None

# %%
missing = [col for col in best_features if col not in valid_df.columns]
assert not missing, f"Missing columns in valid_df: {missing}"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 missing = [col for col in best_features if col not in valid_df.columns]
# ----> 2 assert not missing, f"Missing columns in valid_df: {missing}"
#
# AssertionError: Missing columns in valid_df: ['DayOfWeek', 'FuelPerMinute', 'AvgBagWeight', 'IsWeekend']

# %%
numeric_columns = ['ActualFlightTime', 'ActualTotalFuel',
                   'FlownPassengers', 'BagsCount', 'FlightBagsWeight']

for col in numeric_columns:
    if col in valid_df.columns:
        valid_df[col] = pd.to_numeric(valid_df[col], errors='coerce')

# %%
valid_df["DepartureDate"] = pd.to_datetime(valid_df["DepartureDate"], format="%d/%m/%Y")
valid_df["DayOfWeek"] = valid_df["DepartureDate"].dt.weekday

valid_df["FuelPerMinute"] = valid_df["ActualTotalFuel"] / valid_df["ActualFlightTime"]
valid_df['FuelPerPassenger'] = valid_df['ActualTotalFuel'] / (valid_df['FlownPassengers'])


valid_df["PassengersPerBag"] = valid_df["FlownPassengers"] / valid_df["BagsCount"]
valid_df['AvgBagWeight'] = valid_df['FlightBagsWeight'] / (valid_df['BagsCount'])


valid_df['IsWeekend'] = valid_df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
for col in valid_df.select_dtypes(include='object').columns:
    valid_df[col] = valid_df[col].astype('category')

# %%
valid_df = valid_df[best_features].copy()

# %%
valid_df['PredictedTOW'] = final_model.predict(valid_df)

# %%
valid_df.to_csv("predicted.csv", index=False)
